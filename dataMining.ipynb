# %%
import pandas as pd

# %%
import os
os.listdir()
# Out:
# ['dataMining.ipynb', 'Online Retail Data - Year 2009-2010-2011.csv']

# %%
df = pd.read_csv("Online Retail Data - Year 2009-2010-2011.csv")
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#     InvoiceDate  Price  Customer ID         Country
# 0  12/1/09 7:45   6.95      13085.0  United Kingdom
# 1  12/1/09 7:45   6.75      13085.0  United Kingdom
# 2  12/1/09 7:45   6.75      13085.0  United Kingdom
# 3  12/1/09 7:45   2.10      13085.0  United Kingdom
# 4  12/1/09 7:45   1.25      13085.0  United Kingdom

# %%
df.shape
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044848 entries, 0 to 1044847
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1044848 non-null  object
#  1   StockCode    1044848 non-null  object
#  2   Description  1040573 non-null  object
#  3   Quantity     1044848 non-null  int64
#  4   InvoiceDate  1044848 non-null  object
#  5   Price        1044848 non-null  float64
#  6   Customer ID  809561 non-null   float64
#  7   Country      1044848 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 63.8+ MB
#            Quantity         Price    Customer ID
# count  1.044848e+06  1.044848e+06  809561.000000
# mean   9.993649e+00  4.590546e+00   15319.760422
# std    1.742185e+02  1.217042e+02    1695.812057
# min   -8.099500e+04 -5.359436e+04   12346.000000
# 25%    1.000000e+00  1.250000e+00   13969.000000
# 50%    3.000000e+00  2.100000e+00   15248.000000
# 75%    1.000000e+01  4.130000e+00   16792.000000
# max    8.099500e+04  3.897000e+04   18287.000000

# %%
df.isnull().sum()
# Out:
# Invoice             0
# StockCode           0
# Description      4275
# Quantity            0
# InvoiceDate         0
# Price               0
# Customer ID    235287
# Country             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(11812)

# %%
df.columns = df.columns.str.strip()

# %%
df[df['Quantity'] <= 0]
# Out:
#          Invoice StockCode                       Description  Quantity  \
# 178      C489449     22087          PAPER BUNTING WHITE LACE       -12
# 179      C489449    85206A      CREAM FELT EASTER EGG BASKET        -6
# 180      C489449     21895     POTTING SHED SOW 'N' GROW SET        -4
# 181      C489449     21896                POTTING SHED TWINE        -6
# 182      C489449     22083        PAPER CHAIN KIT RETRO SPOT       -12
# ...          ...       ...                               ...       ...
# 1043387  C581490     23144   ZINC T-LIGHT HOLDER STARS SMALL       -11
# 1044479  C581499         M                            Manual        -1
# 1044653  C581568     21258        VICTORIAN SEWING BOX LARGE        -5
# 1044654  C581569     84978  HANGING HEART JAR T-LIGHT HOLDER        -1
# 1044655  C581569     20979     36 PENCILS TUBE RED RETROSPOT        -5
#
#            InvoiceDate   Price  Customer ID         Country
# 178      12/1/09 10:33    2.95      16321.0       Australia
# 179      12/1/09 10:33    1.65      16321.0       Australia
# 180      12/1/09 10:33    4.25      16321.0       Australia
# 181      12/1/09 10:33    2.10      16321.0       Australia
# 182      12/1/09 10:33    2.95      16321.0       Australia
# ...                ...     ...          ...             ...
# 1043387   12/9/11 9:57    0.83      14397.0  United Kingdom
# 1044479  12/9/11 10:28  224.69      15498.0  United Kingdom
# 1044653  12/9/11 11:57   10.95      15311.0  United Kingdom
# 1044654  12/9/11 11:58    1.25      17315.0  United Kingdom
# 1044655  12/9/11 11:58    1.25      17315.0  United Kingdom
#
# [22557 rows x 8 columns]

# %%
df['Price']
# Out:
# 0           6.95
# 1           6.75
# 2           6.75
# 3           2.10
# 4           1.25
#            ...
# 1044843     2.10
# 1044844     4.15
# 1044845     4.15
# 1044846     4.95
# 1044847    18.00
# Name: Price, Length: 1044848, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.boxplot(df['Quantity'])
plt.title("Quantity Outliers")
plt.show()

# %%
plt.boxplot(df['Price'])
plt.title("Price Outliers")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044848 entries, 0 to 1044847
# Data columns (total 8 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   Invoice      1044848 non-null  object
#  1   StockCode    1044848 non-null  object
#  2   Description  1040573 non-null  object
#  3   Quantity     1044848 non-null  int64
#  4   InvoiceDate  1044848 non-null  object
#  5   Price        1044848 non-null  float64
#  6   Customer ID  809561 non-null   float64
#  7   Country      1044848 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 63.8+ MB
